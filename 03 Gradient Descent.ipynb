# %% [markdown]
# ### Notebook imports and headings

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Example 1: A simple cost function
# $f(x) = x^2 + x + 1$

# %%
def f(x):
  return x**2 + x + 1

# %%
# Make data 
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot 
plt.xlim([-3, 3])
plt.ylim([0, 14])
plt.xlabel("x", fontsize=15)
plt.ylabel("f(x)", fontsize=15)
plt.plot(x_1, f(x_1))
plt.show()
